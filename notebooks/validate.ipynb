# %%
import scipy
import numpy as np
import skimage.io as skio
import pandas as pd

# %%
import json

with open('../cfg/vott-json-export/Ghana-Clouds-export.json') as json_file:  
    data = json.load(json_file)

# %%
for i in data['assets'].keys():
    print(data['assets'][i]['asset']['name'])
    print(data['assets'][i]['regions'])
# Out:
# scene_number_25_forest.png
# []
# scene_number_25_ag-forestry.png
# []
# scene_number_24_water.png
# []
# scene_number_24_savanna.png
# []
# scene_number_25_city.png
# ...

# %%
image = np.zeros((max_x, max_y))
image[coordinates] = 1

# %%
# Out:
#                         image         xmin        ymin         xmax  \
# 0   scene_number_0_forest.png    10.212845    0.000000   337.023885
# 1   scene_number_0_forest.png   629.312633   65.610638   698.357219
# 2   scene_number_0_forest.png   700.658705    4.604255   926.204352
# 3   scene_number_0_forest.png   998.701168   31.078723  1022.866773
# 4   scene_number_0_forest.png  1001.002654    0.000000  1081.554671
# 5   scene_number_0_forest.png   876.722399  299.276596  1082.705414
# 6   scene_number_0_forest.png   828.391189  371.793617   895.134289
# 7   scene_number_0_forest.png   761.648089  435.102128   834.144904
# 8   scene_number_0_forest.png   610.900743  208.342553   730.578025
# 9   scene_number_0_forest.png   305.953822  252.082979   633.915605
# 10  scene_number_0_forest.png   228.854034  613.517021   393.410297
# 11  scene_number_0_forest.png   566.021762  667.617021   734.030255
# 12  scene_number_0_forest.png   525.745754  715.961702   563.720276
# ...
